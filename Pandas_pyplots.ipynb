# %% [markdown]
# <a href="https://colab.research.google.com/github/Salonishah06/DataAnalysis/blob/main/Pandas_pyplots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
car=pd.read_csv('/content/USA_cars_datasets.csv')
car.head(2)
# car.tail(2)
# Out:
#    Unnamed: 0  price   brand    model  year   title_status   mileage   color  \
# 0           0   6300  toyota  cruiser  2008  clean vehicle  274117.0   black
# 1           1   2899    ford       se  2011  clean vehicle  190552.0  silver
#
#                    vin        lot       state country     condition
# 0    jtezu11f88k007763  159348797  new jersey     usa  10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa   6 days left

# %%
car.dtypes
# Out:
# Unnamed: 0        int64
# price             int64
# brand            object
# model            object
# year              int64
# title_status     object
# mileage         float64
# color            object
# vin              object
# lot               int64
# state            object
# country          object
# condition        object
# dtype: object

# %%
car.columns
# Out:
# Index(['Unnamed: 0', 'price', 'brand', 'model', 'year', 'title_status',
#        'mileage', 'color', 'vin', 'lot', 'state', 'country', 'condition'],
#       dtype='object')

# %%
car.describe(include='all')
# Out:
#          Unnamed: 0         price brand model         year   title_status  \
# count   2499.000000   2499.000000  2499  2499  2499.000000           2499
# unique          NaN           NaN    28   127          NaN              2
# top             NaN           NaN  ford  door          NaN  clean vehicle
# freq            NaN           NaN  1235   651          NaN           2336
# mean    1249.000000  18767.671469   NaN   NaN  2016.714286            NaN
# std      721.543484  12116.094936   NaN   NaN     3.442656            NaN
# min        0.000000      0.000000   NaN   NaN  1973.000000            NaN
# 25%      624.500000  10200.000000   NaN   NaN  2016.000000            NaN
# 50%     1249.000000  16900.000000   NaN   NaN  2018.000000            NaN
# 75%     1873.500000  25555.500000   NaN   NaN  2019.000000            NaN
# max     2498.000000  84900.000000   NaN   NaN  2020.000000            NaN
#
#              mileage  color                  vin           lot         state  \
# ...

# %%
car.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'price'}>],
#        [<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'mileage'}>],
#        [<Axes: title={'center': 'lot'}>, <Axes: >]], dtype=object)

# %%
sns.boxplot(x="year",y="mileage",data=car)
# Out:
# <Axes: xlabel='year', ylabel='mileage'>

# %%
sns.pairplot(car)

# %%
car=car.drop(['title_status'],axis=1)
car
# Out:
#       Unnamed: 0  price      brand    model  year   mileage   color  \
# 0              0   6300     toyota  cruiser  2008  274117.0   black
# 1              1   2899       ford       se  2011  190552.0  silver
# 2              2   5350      dodge      mpv  2018   39590.0  silver
# 3              3  25000       ford     door  2014   64146.0    blue
# 4              4  27700  chevrolet     1500  2018    6654.0     red
# ...          ...    ...        ...      ...   ...       ...     ...
# 2494        2494   7800     nissan    versa  2019   23609.0     red
# 2495        2495   9200     nissan    versa  2018   34553.0  silver
# 2496        2496   9200     nissan    versa  2018   31594.0  silver
# 2497        2497   9200     nissan    versa  2018   32557.0   black
# 2498        2498   9200     nissan    versa  2018   31371.0  silver
#
#                       vin        lot       state country      condition
# 0       jtezu11f88k007763  159348797  new jersey     usa   10 days left
# ...

# %%
car=car.rename(columns={"condition":"Days Left"})
car
# Out:
#       Unnamed: 0  price      brand    model  year   mileage   color  \
# 0              0   6300     toyota  cruiser  2008  274117.0   black
# 1              1   2899       ford       se  2011  190552.0  silver
# 2              2   5350      dodge      mpv  2018   39590.0  silver
# 3              3  25000       ford     door  2014   64146.0    blue
# 4              4  27700  chevrolet     1500  2018    6654.0     red
# ...          ...    ...        ...      ...   ...       ...     ...
# 2494        2494   7800     nissan    versa  2019   23609.0     red
# 2495        2495   9200     nissan    versa  2018   34553.0  silver
# 2496        2496   9200     nissan    versa  2018   31594.0  silver
# 2497        2497   9200     nissan    versa  2018   32557.0   black
# 2498        2498   9200     nissan    versa  2018   31371.0  silver
#
#                       vin        lot       state country      Days Left
# 0       jtezu11f88k007763  159348797  new jersey     usa   10 days left
# ...

# %%
car.shape
# Out:
# (2499, 12)

# %%
duplicate_rows_car= car[car.duplicated()]
print("Number of duplicate rows:",duplicate_rows_car.shape)
# Out:
# Number of duplicate rows: (0, 12)

# %%
car.count()
# Out:
# Unnamed: 0    2499
# price         2499
# brand         2499
# model         2499
# year          2499
# mileage       2499
# color         2499
# vin           2499
# lot           2499
# state         2499
# country       2499
# Days Left     2499
# dtype: int64

# %%
car=car.drop_duplicates()
car.count()
# Out:
# Unnamed: 0    2499
# price         2499
# brand         2499
# model         2499
# year          2499
# mileage       2499
# color         2499
# vin           2499
# lot           2499
# state         2499
# country       2499
# Days Left     2499
# dtype: int64

# %%
#find the null values
print(car.isnull().sum())
# Out:
# Unnamed: 0    0
# price         0
# brand         0
# model         0
# year          0
# mileage       0
# color         0
# vin           0
# lot           0
# state         0
# country       0
# Days Left     0
# dtype: int64

# %%
#clean null values
car=car.dropna()
car.count()
# Out:
# Unnamed: 0    2499
# price         2499
# brand         2499
# model         2499
# year          2499
# mileage       2499
# color         2499
# vin           2499
# lot           2499
# state         2499
# country       2499
# Days Left     2499
# dtype: int64

# %%
sns.boxplot(x=car['price'])
# Out:
# <Axes: xlabel='price'>

# %%
#Plotting histogram for number of cars per brand
car.brand.value_counts().nlargest(40).plot(kind='bar',figsize=(10,5))
plt.title("Number of cars by brand")
plt.ylabel("Number of cars")
plt.xlabel("Brands")
# Out:
# Text(0.5, 0, 'Brands')

# %%
# Find the relations between  the variables
plt.figure(figsize=(20,10))
c=car.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
# <ipython-input-26-d1607e28c8f5>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c=car.corr()
#             Unnamed: 0     price      year   mileage       lot
# Unnamed: 0    1.000000  0.098417  0.244921 -0.129258  0.012577
# price         0.098417  1.000000  0.418274 -0.400838  0.159369
# year          0.244921  0.418274  1.000000 -0.594686  0.164582
# mileage      -0.129258 -0.400838 -0.594686  1.000000 -0.130475
# lot           0.012577  0.159369  0.164582 -0.130475  1.000000
